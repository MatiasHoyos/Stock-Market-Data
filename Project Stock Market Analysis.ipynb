# %%
#UPDATE this cell with your data source + Dictionary/Codebook
#data source: https://www.census.gov/data/datasets/time-series/demo/cps/cps-asec.2021.html
#data dictionary: https://www2.census.gov/programs-surveys/cps/datasets/2021/march/asec2021_ddl_pub_full.pdf
#import necessary libaries
import pandas as pd
import matplotlib
import math

#name file path (you will have download your own dataset and populate the path and choose the appropriate cell to execute)
file = 'q1_2022_all[2].csv' # <-- edit this value! 
#you will run just ONE of the next four code blocks, depending on the file type of your dataset
#read data from CSV (.csv) & print head
df = pd.read_csv(file)
print(df.head(100))

#list columns in data frame
print(list(df))
print(len(df))

#output frequency table of chosen column in dataset
col = 'McapRank' #<-edit this value! column name as it appears in dataframe
col_name = 'Market Cap Rank 1>10 in USD' #<-edit this value! descriptive name for column
freq = df[col].value_counts().rename_axis(col_name).reset_index(name='#companies in rank')
freq = freq.sort_values(by = col_name)
print(freq)


#prints updated frequency table
print(freq)
#create frequency chart
ax = freq.plot.barh(x=col_name, y='#companies in rank', rot=0)
# Out:
#         Date Security Ticker  McapRank  TurnRank  VolatilityRank  PriceRank  \
# 0   20220103    Stock      A      10.0       6.0             3.0       10.0
# 1   20220103    Stock     AA       9.0      10.0             5.0        8.0
# 2   20220103    Stock   AACI       3.0       6.0             1.0        4.0
# 3   20220103    Stock   AADI       5.0       3.0             7.0        6.0
# 4   20220103    Stock    AAL       9.0      10.0             6.0        6.0
# ..       ...      ...    ...       ...       ...             ...        ...
# 95  20220103    Stock   AERI       4.0       9.0             7.0        3.0
# 96  20220103    Stock    AES      10.0       5.0             2.0        6.0
# 97  20220103    Stock   AESE       2.0       9.0             8.0        1.0
# 98  20220103    Stock   AEVA       7.0       5.0             7.0        3.0
# 99  20220103    Stock    AEY       1.0       8.0             8.0        1.0
#
#     LitVol('000)  OrderVol('000)   Hidden  TradesForHidden  HiddenVol('000)  \
# 0        591.729       23481.036   4642.0          18622.0          212.129
# 1       2506.322       69988.650   6116.0          33837.0          418.112
# 2          3.799          51.677     30.0             43.0            5.768
# 3         24.267        1329.856    353.0           1035.0           10.723
# 4      17774.883      527357.774  14865.0         108766.0         2530.589
# ..           ...             ...      ...              ...              ...
# 95       308.500       13048.609    711.0           4978.0           56.210
# 96      1328.915       60716.311   1944.0          16126.0          175.241
# 97       136.176        2964.083     62.0            541.0            6.406
# 98       425.746       17557.226    800.0           5493.0           73.788
# 99        25.977         682.880     14.0            118.0            9.757
#
#     TradeVolForHidden('000)    Cancels  LitTrades  OddLots  TradesForOddLots  \
# 0                   803.858   210270.0    13797.0  14213.0           18438.0
# 1                  2924.434   530404.0    27570.0  20672.0           33681.0
# 2                     9.567      202.0       12.0      3.0              41.0
# 3                    34.990    12883.0      679.0    875.0            1032.0
# 4                 20305.472  1574661.0    93353.0  32576.0          108171.0
# ..                      ...        ...        ...      ...               ...
# 95                  364.710    75714.0     4249.0   2915.0            4959.0
# 96                 1504.156   340151.0    14017.0   6372.0           15957.0
# 97                  142.582     7445.0      478.0    176.0             540.0
# 98                  499.534    77277.0     4678.0   2680.0            5474.0
# 99                   35.734     3139.0      104.0     29.0             118.0
#
#     OddLotVol('000)  TradeVolForOddLots('000)
# 0           328.650                   792.105
# 1           638.804                  2916.690
# 2             0.160                     9.387
# 3            16.453                    34.974
# 4          1102.688                 20225.347
# ..              ...                       ...
# 95           77.577                   363.187
# 96          174.500                  1498.730
# 97            5.950                   142.282
# 98           67.183                   497.421
# 99            0.893                    35.734
#
# [100 rows x 19 columns]
# ['Date', 'Security', 'Ticker', 'McapRank', 'TurnRank', 'VolatilityRank', 'PriceRank', "LitVol('000)", "OrderVol('000)", 'Hidden', 'TradesForHidden', "HiddenVol('000)", "TradeVolForHidden('000)", 'Cancels', 'LitTrades', 'OddLots', 'TradesForOddLots', "OddLotVol('000)", "TradeVolForOddLots('000)"]
# 442329
#    Market Cap Rank 1>10 in USD  #companies in rank
# 0                          1.0               69612
# 2                          2.0               69486
# 3                          3.0               69397
# 1                          4.0               69501
# 6                          5.0               27378
# 8                          6.0               27370
# 9                          7.0               27368
# 5                          8.0               27381
# 7                          9.0               27370
# 4                         10.0               27403
#    Market Cap Rank 1>10 in USD  #companies in rank
# 0                          1.0               69612
# 2                          2.0               69486
# 3                          3.0               69397
# 1                          4.0               69501
# 6                          5.0               27378
# 8                          6.0               27370
# 9                          7.0               27368
# 5                          8.0               27381
# 7                          9.0               27370
# 4                         10.0               27403
